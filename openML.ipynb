# %%
import pandas as pd
import numpy as np
import sklearn as sk
import openml
import altair as alt
from vega_datasets import data

# %%
dataset = openml.datasets.get_dataset(31)

X, y, categorical_indicator, attribute_names = dataset.get_data(
    dataset_format="dataframe", target=dataset.default_target_attribute)

# %%
X
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0         6  critical/other existing credit
# 1          0<=X<200        48                   existing paid
# 2       no checking        12  critical/other existing credit
# 3                <0        42                   existing paid
# 4                <0        24              delayed previously
# ..              ...       ...                             ...
# 995     no checking        12                   existing paid
# 996              <0        30                   existing paid
# 997     no checking        12                   existing paid
# 998              <0        45                   existing paid
# 999        0<=X<200        45  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv         1169.0  no known savings         >=7
# 1               radio/tv         5951.0              <100      1<=X<4
# ...

# %%
alt.Chart(X).mark_bar().encode(
    alt.X("credit_amount:Q", bin=True),
    y='count()',
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(X).mark_bar().encode(x=alt.X("purpose:N"),
                               y=alt.Y('count():Q', sort=alt.SortField("sort_val", order="ascending")))
# Out:
# alt.Chart(...)

# %%
data = pd.DataFrame({'a': list('CCCDDDEEE'), 'b': [2, 7, 4, 1, 2, 6, 8, 4, 7]})

# %%
chart = alt.Chart(data)
alt.Chart(data).mark_point().encode(x='a', y='b')
# Out:
# alt.Chart(...)
